# %%
import gym

env = gym.make("Humanoid-v2")
for i in range(100):
    done = False
    obs = env.reset()
    while not done:
        act = env.action_space.sample()
        obs_, re, done, info = env.step(act)
        #env.render()
        print(act)
# Out:
# [ 0.01604299 -0.296563    0.15970688  0.25416842  0.06216846  0.00528366
#   0.27640247 -0.12216445  0.28926137 -0.29662895  0.28538433  0.04237823
#   0.24058323 -0.19816902 -0.07711556  0.3455778  -0.3636534 ]
# [-0.16544253  0.11150526 -0.2595744   0.14893639  0.2384387  -0.31676757
#   0.23761535  0.14207414 -0.26396745  0.35973072 -0.3426845  -0.09345536
#   0.3983431  -0.17138273  0.23232386 -0.11893266  0.06183442]
# [-0.22802594  0.26027632  0.12906356  0.02205691 -0.32599127 -0.15165389
#  -0.25274473  0.04534031  0.2153901  -0.10422298  0.3005095  -0.23044457
#  -0.04696903 -0.02694848 -0.00757839 -0.23440622  0.36031222]
# [ 0.16378653 -0.27154443 -0.03110963  0.09951587 -0.25294805  0.35992014
#  -0.23968452 -0.33194745  0.1772103  -0.16819704  0.01621037 -0.15617706
#  -0.32538554  0.0108156   0.25880748  0.08670758  0.00387955]
# [-0.14764774  0.04895634  0.05584246 -0.3427171   0.10320679 -0.1284386
# ...
