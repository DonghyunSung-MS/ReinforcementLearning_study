# %%
from dqn_policy import dqnPolicy
from modelMDP import Mdp
pol = dqnPolicy(policy_choice='optimalNoise') # bad,random, optimal, optimalNoise
#print(pol.policy)


print("Run one simulation")
mdp = Mdp(pol.policy)
mdp.run_one_simulation()

print("Run many simulation")
mdp.run_many_simulation()
# Out:
# Run one simulation
# s:  0, a: 2, r: -0.02, sl:  1, done: 0, info: prob : 0.9318181818181819, final reward: None
# s:  1, a: 2, r: -0.02, sl:  2, done: 0, info: prob : 0.9318181818181819, final reward: None
# s:  2, a: 2, r: -0.02, sl:  3, done: 1, info: prob : 0.9318181818181819, final reward: 1
# Run many simulation
# Number of simulations : 1000
# Sucees rate           : 0.957

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-81066d3a41c5> in <module>
# ----> 1 import retro
#
# ModuleNotFoundError: No module named 'retro'
